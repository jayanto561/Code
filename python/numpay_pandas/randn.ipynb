# %%
import numpy as np

# %%
np.random.randn(20)
# Out:
# array([-0.90604869,  1.4281641 , -0.15116471, -1.8572671 , -0.36434513,
#         0.02919821,  0.6813791 , -1.01607109, -2.2221528 ,  0.25670183,
#         0.62398957, -1.01526771,  1.23574479, -0.0276109 ,  0.8104502 ,
#         0.33082854, -0.06705444,  0.53360787, -0.33722751, -1.12391286])

# %%
ar=np.random.randn(1000,1)
ar
# Out:
# array([[ 1.26747068e-01],
#        [-2.23242929e+00],
#        [-1.99531864e-01],
#        [-6.98569017e-01],
#        [-7.02524324e-01],
#        [-2.60213410e-02],
#        [ 1.54710107e+00],
#        [ 6.98679314e-02],
#        [-3.76250389e-01],
#        [-1.11153966e+00],
#        [-2.11798024e-01],
#        [ 4.58746651e-01],
#        [-2.39907884e-01],
#        [ 1.18599284e+00],
#        [ 6.28069598e-02],
#        [-3.61645304e-01],
#        [ 6.94558634e-01],
#        [-3.61721288e-01],
#        [-1.07211559e+00],
#        [ 1.16114635e+00],
#        [-6.61921517e-01],
#        [-2.38135552e-01],
#        [-2.19810814e+00],
#        [ 1.81596867e+00],
#        [ 1.61065991e-01],
#        [ 5.37654123e-01],
#        [-9.33364122e-02],
#        [-1.85251907e+00],
#        [-6.57632876e-01],
#        [-5.45396432e-01],
#        [-1.51569330e+00],
#        [ 1.02518428e+00],
#        [-5.20723865e-02],
#        [ 2.22587978e-01],
#        [-1.20673043e-01],
# ...

# %%
import pandas as pd

# %%
df=pd.DataFrame(data=ar,columns=['A'])
df
# Out:
#             A
# 0    0.126747
# 1   -2.232429
# 2   -0.199532
# 3   -0.698569
# 4   -0.702524
# ..        ...
# 995  0.738486
# 996 -1.194509
# 997 -1.421845
# 998  0.508744
# 999 -0.335851
#
# [1000 rows x 1 columns]

# %%
df['A'].hist(bins=100)
# Out:
# <Axes: >
